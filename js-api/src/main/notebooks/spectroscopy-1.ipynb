// %%
const eqSpectro = require("../../../target/eqfiddle-api");

// %%
eqSpectro.LTBTS()
// Out:
// evalmachine.<anonymous>:1
// eqSpectro.LTBTS()
//           ^
//
// TypeError: eqSpectro.LTBTS is not a function
//     at evalmachine.<anonymous>:1:11
//     at Script.runInThisContext (node:vm:129:12)
//     at Object.runInThisContext (node:vm:305:38)
//     at run ([eval]:1020:15)
//     at onRunRequest ([eval]:864:18)
//     at onMessage ([eval]:828:13)
//     at process.emit (node:events:390:28)
//     at emit (node:internal/child_process:917:12)
//     at processTicksAndRejections (node:internal/process/task_queues:84:21)

// %%
const ltsSpec = {
  "lts": {
    "initialState": "P0",
    "states": {
      "P5": {
        "transitions": [],
        "ccs": "0"
      },
      "P0": {
        "transitions": [
          {
            "label": "a",
            "target": "P1"
          },
          {
            "label": "a",
            "target": "P2"
          }
        ],
        "ccs": "a.(b.(0) + c.(d.(0))) + a.(f.(0) + c.(g.(0)))"
      },
      "P1": {
        "transitions": [
          {
            "label": "b",
            "target": "P5"
          },
          {
            "label": "c",
            "target": "P3"
          }
        ],
        "ccs": "b.(0) + c.(d.(0))"
      },
      "P2": {
        "transitions": [
          {
            "label": "f",
            "target": "P5"
          },
          {
            "label": "c",
            "target": "P4"
          }
        ],
        "ccs": "f.(0) + c.(g.(0))"
      },
      "P3": {
        "transitions": [
          {
            "label": "d",
            "target": "P5"
          }
        ],
        "ccs": "d.(0)"
      },
      "P4": {
        "transitions": [
          {
            "label": "g",
            "target": "P5"
          }
        ],
        "ccs": "g.(0)"
      }
    },
    "_id": "6256a7d5b5d5c91834cb17e2"
  }
};

const lts = eqSpectro.loadLTS(ltsSpec);
lts;
// Out:
// $c_Lde_bbisping_eqfiddle_spectroscopy_EquivalenceSpectroscopeAPI$WeakTS {
//   'step$1': $c_Lde_bbisping_eqfiddle_util_LabeledRelation {
//     'tupleSet$1': $c_sci_HashSet$HashTrieSet {
//       'bitmap$5': 142868758,
//       'elems$5': [ArrayClass],
//       'size0$5': 8
//     },
//     'inverseRep$1': null,
//     'lhs$1': null,
//     'labels$1': $c_sci_$colon$colon {
//       'head$5': 'd',
//       'tl$5': [$c_sci_$colon$colon]
//     },
//     'rhs$1': null,
//     'rep$1': $c_sci_MapLike$$anon$2 {
//       'f$4': $c_Lde_bbisping_eqfiddle_util_LabeledRelation$$anonfun$$lessinit$greater$2 {},
//       '$$outer$4': [$c_sci_HashMap$HashTrieMap]
//     },
//     'bitmap$0$1': 9
//   },
//   'nodeLabeling$1': $c_sci_HashMap$HashTrieMap {
//     'bitmap$6': 67125928,
//     'elems$6': ArrayClass { u: [Array] },
//     'size0$6': 6
//   },
//   'nodes$1': $c_sci_MapLike$ImmutableDefaultKeySet {
//     '$$outer$4': $c_sci_HashMap$HashTrieMap {
//       'bitmap$6': 67125928,
//       'elems$6': [ArrayClass],
//       'size0$6': 6
//     }
//   },
//   'nodesByLabel$1': $c_sci_MapLike$$anon$2 {
//     'f$4': $c_sjsr_AnonFunction1 { 'f$2': [Function (anonymous)] },
//     '$$outer$4': $c_sci_HashMap$HashTrieMap {
//       'bitmap$6': 273678376,
//       'elems$6': [ArrayClass],
//       'size0$6': 6
//     }
//   },
//   'actions$1': $c_sci_$colon$colon {
//     'head$5': 'd',
//     'tl$5': $c_sci_$colon$colon {
//       'head$5': 'c',
//       'tl$5': [$c_sci_$colon$colon]
//     }
//   },
//   'silentActions$2': $c_sci_Set$Set1 { 'elem1$4': 'tau' },
//   'silentSteps$2': $c_Lde_bbisping_eqfiddle_util_Relation {
//     'tupleSet$1': null,
//     'inverseRep$1': null,
//     'lhs$1': null,
//     'rhs$1': null,
//     'domain$1': null,
//     'rep$1': $c_sci_MapLike$$anon$2 {
//       'f$4': $c_Lde_bbisping_eqfiddle_util_Relation$$anonfun$$lessinit$greater$2 {},
//       '$$outer$4': $c_sci_Map$EmptyMap$ {}
//     },
//     'bitmap$0$1': 0
//   },
//   'silentReachableCache$2': $c_scm_HashMap {
//     '$$undloadFactor$5': 750,
//     'table$5': ArrayClass { u: [Array] },
//     'tableSize$5': 0,
//     'threshold$5': 12,
//     'sizemap$5': null,
//     'seedvalue$5': 4
//   },
//   'silentReachableInverse$2': $c_sci_Map$EmptyMap$ {}
// }

// %%
const spectroResult = eqSpectro.performSpectroscopy(lts, "P0", "P2");
spectroResult;
// Out:
// [
//   {
//     left: 'P0',
//     right: 'P2',
//     distinctions: [ [Object] ],
//     preorderings: []
//   },
//   {
//     left: 'P2',
//     right: 'P0',
//     distinctions: [ [Object], [Object] ],
//     preorderings: []
//   }
// ]
